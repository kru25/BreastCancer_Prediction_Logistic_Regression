# %%
#importing libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
#importing the breast cancer dataset
df=pd.read_csv("breast_cancer.csv")
X=df.iloc[:,1:-1].values
y=df.iloc[:,-1].values
df
# Out:
#      Sample code number  Clump Thickness  Uniformity of Cell Size  \
# 0               1000025                5                        1
# 1               1002945                5                        4
# 2               1015425                3                        1
# 3               1016277                6                        8
# 4               1017023                4                        1
# 5               1017122                8                       10
# 6               1018099                1                        1
# 7               1018561                2                        1
# 8               1033078                2                        1
# 9               1033078                4                        2
# 10              1035283                1                        1
# 11              1036172                2                        1
# 12              1041801                5                        3
# ...

# %%
df.shape
# Out:
# (683, 11)

# %%
#Splitting the data into test and training data
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.25,random_state=0)

# %%
#training the train data on logistic Regression model
from sklearn.linear_model import LogisticRegression
logres=LogisticRegression(random_state=0)
logres.fit(X_train,y_train)
# Out:
# C:\Users\KRUTER\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:433: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#           intercept_scaling=1, max_iter=100, multi_class='warn',
#           n_jobs=None, penalty='l2', random_state=0, solver='warn',
#           tol=0.0001, verbose=0, warm_start=False)

# %%
#Prediction of the test values
y_pred=logres.predict(X_test)
np.concatenate((y_test.reshape(len(y_test),1),y_pred.reshape(len(y_pred),1)),1)
# Out:
# array([[2, 2],
#        [2, 2],
#        [4, 4],
#        [4, 4],
#        [2, 2],
#        [2, 2],
#        [2, 2],
#        [4, 4],
#        [2, 2],
#        [2, 2],
#        [4, 4],
#        [2, 2],
#        [4, 4],
#        [2, 2],
#        [2, 2],
#        [2, 2],
#        [4, 4],
#        [4, 4],
#        [4, 4],
#        [2, 2],
#        [2, 2],
#        [2, 2],
#        [4, 4],
#        [2, 2],
#        [4, 4],
#        [4, 4],
#        [2, 2],
#        [2, 2],
#        [2, 2],
#        [4, 4],
#        [2, 2],
#        [4, 4],
#        [4, 4],
#        [2, 2],
#        [2, 2],
#        [2, 2],
#        [4, 4],
#        [4, 4],
#        [2, 2],
#        [4, 4],
#        [2, 2],
#        [2, 2],
#        [2, 2],
#        [2, 2],
#        [2, 2],
#        [2, 2],
#        [2, 2],
#        [4, 4],
#        [2, 2],
#        [2, 2],
#        [4, 4],
#        [2, 2],
#        [4, 4],
#        [2, 2],
#        [2, 2],
#        [2, 2],
#        [4, 4],
#        [2, 4],
# ...

# %%
#Evaluating model using Accuracy score and confusion matrix
from sklearn.metrics import confusion_matrix,accuracy_score
cm=confusion_matrix(y_test,y_pred)
print(cm)
accuracy_score(y_test,y_pred)
# Out:
# [[103   4]
#  [  8  56]]
# 0.9298245614035088

# %%
#evaluating using k-fold cross validation
from sklearn.model_selection import cross_val_score
accuracies=cross_val_score(estimator=logres,X=X_train,y=y_train,cv=5)
print("Accuracy of the model :",accuracies.mean())
print("Standard Deviation of the accuracies :",accuracies.std())
# Out:
# Accuracy of the model : 0.9706834189986674
# Standard Deviation of the accuracies : 0.01383867628202393
# C:\Users\KRUTER\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:433: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\Users\KRUTER\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:433: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\Users\KRUTER\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:433: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\Users\KRUTER\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:433: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# ...
